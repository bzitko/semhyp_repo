# %% [markdown]
# # SemHyP (Semantic Hypergraph Parser)
#
# ## Module for semantic hypergraph parsing from textual annotations
#
# This notebook demonstrates the usage of Semantic Hypergraph Parser module `semhyp`. The follow functionalities are covered:
#
# 1. Reading annotated text
# 2. Visualizing annotated text
# 3. Parsing annotated text into semantic hypergraph
# 4. Visualizing semantic hypergraph

# %%
import semhyp

# %% [markdown]
# ## 1. Reading annotated text
#
# An example of an annotated sentence in CoNLL-X format is provided below:
#
# ```
# # Patrick knew about IBM's plans, but he was ready to ignore them.
# 0 0  Patrick + Patrick PROPN NNP nsubj 1  B-PERSON -         B-ARG0 O      O      B-MAIN1 O       -
# 0 1  knew    + know    VERB  VBD ROOT  1  O        know.01   B-V    O      O      O       O       know.v.01
# 0 2  about   + about   ADP   IN  prep  1  O        -         B-ARG1 O      O      O       O       -
# 0 3  IBM     - IBM     PROPN NNP poss  5  B-ORG    -         I-ARG1 O      O      O       B-MAIN2 -
# 0 4  's      + 's      PART  POS case  3  O        -         I-ARG1 O      O      O       I-MAIN2 -
# 0 5  plans   - plan    NOUN  NNS pobj  2  O        -         I-ARG1 O      O      O       I-MAIN2 plan.n.01
# 0 6  ,       + ,       PUNCT ,   punct 1  O        -         O      O      O      O       O       -
# 0 7  but     + but     CCONJ CC  cc    1  O        -         O      O      O      O       O       -
# 0 8  he      + he      PRON  PRP nsubj 9  O        -         O      B-ARG1 B-ARG0 B-REF1  O       -
# 0 9  was     + be      AUX   VBD conj  1  O        be.01     O      B-V    O      O       O       -
# 0 10 ready   + ready   ADJ   JJ  acomp 9  O        -         O      B-ARG2 O      O       O       ready.a.01
# 0 11 to      + to      PART  TO  aux   12 O        -         O      I-ARG2 O      O       O       -
# 0 12 ignore  + ignore  VERB  VB  xcomp 10 O        ignore.01 O      I-ARG2 B-V    O       O       ignore.v.01
# 0 13 them    - they    PRON  PRP dobj  12 O        -         O      I-ARG2 B-ARG1 O       B-REF2  -
# 0 14 .       + .       PUNCT .   punct 9  O        -         O      O      O      O       O       -
# ```
#
# Each row represents a token in the sentence with various annotations. The columns are as follows:
#
# 1. **Sentence ID**: The ID of the sentence in the document (0 for the first sentence).
# 2. **Token ID**: The position of the token in the sentence.
# 3. **Token**: The original token in the sentence.
# 4. **Space**: Is token followed by space.
# 5. **Lemma**: The base form of the token.
# 6. **POS**: Part of Speech tag.
# 7. **Detailed POS**: More specific POS tag.
# 8. **Dependency Relation**: Syntactic dependency relation to the head of the sentence.
# 9. **Head ID**: The ID of the head token in the dependency tree.
# 10. **NER**: Named Entity Recognition tag.
# 11. **FrameNet**: FrameNet annotation.
# 12. **SRL**:  Semantic Role Label of the verb "knew" in the sentence.
# 13. **SRL**:  Semantic Role Label of the verb "was" in the sentence.
# 14. **SRL**:  Semantic Role Label of the verb "ignore" in the sentence.
# 15. **Coreference**: Coreference chain for token "he".
# 16. **Coreference**: Coreference chain for token "them".
# 17. **WordNet**: WordNet sense.

# %%
FILENAME = "dataset/patrick.txt"

annotated_text = open(FILENAME).read()
annotated_text
# Out:
# "# Patrick knew about IBM's plans, but he was ready to ignore them.\n0 0  Patrick + Patrick PROPN NNP nsubj 1  B-PERSON -         B-ARG0 O      O      B-MAIN1 O       -\n0 1  knew    + know    VERB  VBD ROOT  1  O        know.01   B-V    O      O      O       O       know.v.01\n0 2  about   + about   ADP   IN  prep  1  O        -         B-ARG1 O      O      O       O       -\n0 3  IBM     - IBM     PROPN NNP poss  5  B-ORG    -         I-ARG1 O      O      O       B-MAIN2 -\n0 4  's      + 's      PART  POS case  3  O        -         I-ARG1 O      O      O       I-MAIN2 -\n0 5  plans   - plan    NOUN  NNS pobj  2  O        -         I-ARG1 O      O      O       I-MAIN2 plan.n.01\n0 6  ,       + ,       PUNCT ,   punct 1  O        -         O      O      O      O       O       -\n0 7  but     + but     CCONJ CC  cc    1  O        -         O      O      O      O       O       -\n0 8  he      + he      PRON  PRP nsubj 9  O        -         O      B-ARG1 B-ARG0 B-REF1  O       -\n0 9  was     + be      AUX   VBD conj  1  O        be.01     O      B-V    O      O       O       -\n0 10 ready   + ready   ADJ   JJ  acomp 9  O        -         O      B-ARG2 O      O       O       ready.a.01\n0 11 to      + to      PART  TO  aux   12 O        -         O      I-ARG2 O      O       O       -\n0 12 ignore  + ignore  VERB  VB  xcomp 10 O        ignore.01 O      I-ARG2 B-V    O       O       ignore.v.01\n0 13 them    - they    PRON  PRP dobj  12 O        -         O      I-ARG2 B-ARG1 O       B-REF2  -\n0 14 .       + .       PUNCT .   punct 9  O        -         O      O      O      O       O       -\n# He focused on his own plan, believing his team could still succeed.\n1 0  He        + he      PRON  PRP  nsubj  1  O -          B-ARG0     B-ARG0 O   O          B-REF1 O       -\n1 1  focused   + focus   VERB  VBD  ROOT   1  O focus.01   B-V        O      O   O          O      O       concentrate.v.02\n1 2  on        + on      ADP   IN   prep   1  O -          B-ARG2     O      O   O          O      O       -\n1 3  his       + his     PRON  PRP$ poss   5  O -          I-ARG2     O      O   O          B-REF1 O       -\n1 4  own       + own     ADJ   JJ   amod   5  O -          I-ARG2     O      O   O          O      O       own.s.01\n1 5  plan      - plan    NOUN  NN   pobj   2  O -          I-ARG2     O      O   O          O      O       plan.n.01\n1 6  ,         + ,       PUNCT ,    punct  1  O -          O          O      O   O          O      O       -\n1 7  believing + believe VERB  VBG  advcl  1  O believe.01 B-ARGM-PRD B-V    O   O          O      O       believe.v.03\n1 8  his       + his     PRON  PRP$ poss   9  O -          I-ARGM-PRD B-ARG1 O   B-ARG0     B-REF1 B-MAIN3 -\n1 9  team      + team    NOUN  NN   nsubj  12 O -          I-ARGM-PRD I-ARG1 O   I-ARG0     O      I-MAIN3 team.n.01\n1 10 could     + could   AUX   MD   aux    12 O -          I-ARGM-PRD I-ARG1 B-V B-ARGM-MOD O      O       -\n1 11 still     + still   ADV   RB   advmod 12 O -          I-ARGM-PRD I-ARG1 O   B-ARGM-TMP O      O       still.r.01\n1 12 succeed   - succeed VERB  VB   ccomp  7  O succeed.01 I-ARGM-PRD I-ARG1 O   B-V        O      O       succeed.v.01\n1 13 .         + .       PUNCT .    punct  1  O -          O          O      O   O          O      O       -\n# They just needed to stay on course and work together.\n2 0  They     + they     PRON  PRP nsubj  2 O -       B-ARG0     B-ARG1 B-ARG0     B-REF3 -\n2 1  just     + just     ADV   RB  advmod 2 O -       B-ARGM-ADV O      O          O      merely.r.01\n2 2  needed   + need     VERB  VBD ROOT   2 O need.01 B-V        O      O          O      necessitate.v.01\n2 3  to       + to       PART  TO  aux    4 O -       B-ARG1     O      O          O      -\n2 4  stay     + stay     VERB  VB  xcomp  2 O stay.01 I-ARG1     B-V    O          O      stay.v.01\n2 5  on       + on       ADP   IN  prep   4 O -       I-ARG1     B-ARG3 O          O      -\n2 6  course   + course   NOUN  NN  pobj   5 O -       ...

# %% [markdown]
# The function `semhyp.read` is used to read the textual annotations of the sentences. The final result is a `doc` object, which is similar to the one used by **spaCy**.

# %%
doc = semhyp.read(FILENAME)
doc
# Out:
# Patrick knew about IBM's plans, but he was ready to ignore them. He focused on his own plan, believing his team could still succeed. They just needed to stay on course and work together.

# %% [markdown]
# This code snippet demonstrates how to:
#
# 1. Iterate over sentences in the `doc` object.
# 2. Iterate over tokens in each sentence and print their text, lemma, part of speech, dependency relation, head token, roleset and synset.
# 3. Print named entities in each sentence.
# 4. Print semantic roles in each sentence
# 4. Print coreference chains in each sentence.

# %%
# Assuming `doc` is the object returned by `semhyp.read`

# Iterate over sentences in the doc
for sent in doc.sents:
    print("Sentence:", sent.text)
    print("Sentence index:", sent.label)
    
    # Iterate over tokens in the sentence
    for token in sent:
        print(f" Token: {token.text}, Index: {token.i}, Lemma: {token.lemma}, POS: {token.pos}, Dependency: {token.dep}, Head: {token.head.text}, Roleset: {token.roleset}, Synset: {token.synset}")

    # Print named entities in the sentence
    for ent in sent.ent:
        print(f" Entity: {ent.text}, Label: {ent.label}")

    # Print semantic roles in the sentence
    for verb_token in sent.srl:
        print(f" Verb: {verb_token.text}")
        for arg in sent.srl[verb_token]:
            print(f"  Argument: {arg.text}, Label: {arg.label}")

    # Print coreference chains in the sentence
    for chain in sent.coref:
        print(f" Coreference chain: {chain}")
        for mention in sent.coref[chain]:
            print(f"  Mention: {mention.text}, Label: {mention.label}")
    print("\n")
# Out:
# Sentence: Patrick knew about IBM's plans, but he was ready to ignore them.
# Sentence index: 0
#  Token: Patrick, Index: 0, Lemma: Patrick, POS: PROPN, Dependency: nsubj, Head: knew, Roleset: None, Synset: None
#  Token: knew, Index: 1, Lemma: know, POS: VERB, Dependency: ROOT, Head: knew, Roleset: know.01, Synset: know.v.01
#  Token: about, Index: 2, Lemma: about, POS: ADP, Dependency: prep, Head: knew, Roleset: None, Synset: None
#  Token: IBM, Index: 3, Lemma: IBM, POS: PROPN, Dependency: poss, Head: plans, Roleset: None, Synset: None
#  Token: 's, Index: 4, Lemma: 's, POS: PART, Dependency: case, Head: IBM, Roleset: None, Synset: None
#  Token: plans, Index: 5, Lemma: plan, POS: NOUN, Dependency: pobj, Head: about, Roleset: None, Synset: plan.n.01
#  Token: ,, Index: 6, Lemma: ,, POS: PUNCT, Dependency: punct, Head: knew, Roleset: None, Synset: None
#  Token: but, Index: 7, Lemma: but, POS: CCONJ, Dependency: cc, Head: knew, Roleset: None, Synset: None
#  Token: he, Index: 8, Lemma: he, POS: PRON, Dependency: nsubj, Head: was, Roleset: None, Synset: None
#  Token: was, Index: 9, Lemma: be, POS: AUX, Dependency: conj, Head: knew, Roleset: be.01, Synset: None
#  Token: ready, Index: 10, Lemma: ready, POS: ADJ, Dependency: acomp, Head: was, Roleset: None, Synset: ready.a.01
#  Token: to, Index: 11, Lemma: to, POS: PART, Dependency: aux, Head: ignore, Roleset: None, Synset: None
#  Token: ignore, Index: 12, Lemma: ignore, POS: VERB, Dependency: xcomp, Head: ready, Roleset: ignore.01, Synset: ignore.v.01
#  Token: them, Index: 13, Lemma: they, POS: PRON, Dependency: dobj, Head: ignore, Roleset: None, Synset: None
#  Token: ., Index: 14, Lemma: ., POS: PUNCT, Dependency: punct, Head: was, Roleset: None, Synset: None
#  Entity: Patrick, Label: PERSON
#  Entity: IBM, Label: ORG
#  Verb: knew
#   Argument: Patrick, Label: ARG0
#   Argument: knew, Label: V
#   Argument: about IBM's plans, Label: ARG1
#  Verb: was
#   Argument: he, Label: ARG1
#   Argument: was, Label: V
#   Argument: ready to ignore them, Label: ARG2
#  Verb: ignore
#   Argument: he, Label: ARG0
#   Argument: ignore, Label: V
#   Argument: them, Label: ARG1
#  Coreference chain: 1
#   Mention: Patrick, Label: MAIN1
#   Mention: he, Label: REF1
#  Coreference chain: 2
#   Mention: IBM's plans, Label: MAIN2
#   Mention: them, Label: REF2
#
#
# Sentence: He focused on his own plan, believing his team could still succeed.
# Sentence index: 1
#  Token: He, Index: 15, Lemma: he, POS: PRON, Dependency: nsubj, Head: focused, Roleset: None, Synset: None
#  Token: focused, Index: 16, Lemma: focus, POS: VERB, Dependency: ROOT, Head: focused, Roleset: focus.01, Synset: concentrate.v.02
#  Token: on, Index: 17, Lemma: on, POS: ADP, Dependency: prep, Head: focused, Roleset: None, Synset: None
#  Token: his, Index: 18, Lemma: his, POS: PRON, Dependency: poss, Head: plan, Roleset: None, Synset: None
#  Token: own, Index: 19, Lemma: own, POS: ADJ, Dependency: amod, Head: plan, Roleset: None, Synset: own.s.01
#  Token: plan, Index: 20, Lemma: plan, POS: NOUN, Dependency: pobj, Head: on, Roleset: None, Synset: plan.n.01
#  Token: ,, Index: 21, Lemma: ,, POS: PUNCT, Dependency: punct, Head: focused, Roleset: None, Synset: None
#  Token: believing, Index: 22, Lemma: believe, POS: VERB, Dependency: advcl, Head: focused, Roleset: believe.01, Synset: believe.v.03
#  Token: his, Index: 23, Lemma: his, POS: PRON, Dependency: poss, Head: team, Roleset: None, Synset: None
#  Token: team, Index: 24, Lemma: team, POS: NOUN, Dependency: nsubj, Head: succeed, Roleset: None, Synset: team.n.01
#  Token: could, Index: 25, Lemma: could, POS: AUX, Dependency: aux, Head: succeed, Roleset: None, Synset: None
#  Token: still, Index: 26, Lemma: still, POS: ADV, Dependency: advmod, Head: succeed, Roleset: None, Synset: still.r.01
#  Token: succeed, Index: 27, Lemma: succeed, POS: VERB, Dependency: ccomp, Head: believing, Roleset: succeed.01, Synset: succeed.v.01
#  Token: ., Index: 28, Lemma: ., POS: PUNCT, Dependency: punct, Head: focused, Roleset: None, Synset: None
#  Verb: focused
#   Argument: He, Label: ARG0
#   Argument: focused, Label: V
#   Argument: on his own plan, Label: ARG2
#   Argument: believing his team could still succeed, Label: ARGM-PRD
#  Verb: believing
#   Argument: He, Label: ARG0
#   Argument: believing, Label: V
#   Argument: his team could still succeed, Label: ARG1
#  Verb: could
#   Argument: could, Label: V
#  Verb: succeed
#   Argument: his team, Label: ARG0
#   Argument: could, Label: ARGM-MOD
#   Argument: still, Label: ARGM-TMP
#   Argument: succeed, Label: V
#  Coreference chain: 1
#   Mention: He, Label: REF1
#   Mention: his, Label: REF1
#   Mention: his, Label: REF1
#  Coreference chain: 3
#   Mention: his team, Label: MAIN3
#
#
# Sentence: They just needed to stay on course and work together.
# Sentence index: 2
#  Token: They, Index: 29, Lemma: they, POS: PRON, Dependency: nsubj, Head: needed, Roleset: None, Synset: None
#  Token: just, Index: 30, Lemma: just, POS: ADV, Dependency: advmod, Head: needed, Roleset: None, Synset: merely.r.01
#  Token: needed, Index: 31, Lemma: need, POS: VERB, Dependency: ROOT, Head: needed, Roleset: need.01, Synset: necessitate.v.01
#  Token: to, Index: 32, Lemma: to, POS: PART, Dependency: aux, Head: stay, Roleset: None, Synset: None
#  Token: stay, Index: 33, Lemma: stay, POS: VERB, Dependency: xcomp, Head: needed, Roleset: stay.01, Synset: stay.v.01
#  Token: on, Index: 34, Lemma: on, POS: ADP, Dependency: prep, Head: stay, Roleset: None, Synset: None
#  Token: course, Index: 35, Lemma: course, POS: NOUN, Dependency: pobj, Head: on, Roleset: None, Synset: path.n.04
#  Token: and, Index: 36, Lemma: and, POS: CCONJ, Dependency: cc, Head: stay, Roleset: None, Synset: None
#  Token: work, Index: 37, Lemma: work, POS: VERB, Dependency: conj, Head: stay, Roleset: work.01, Synset: work.v.01
#  Token: together, Index: 38, Lemma: together, POS: ADV, Dependency: advmod, Head: work, Roleset: None, Synset: together.r.02
#  Token: ., Index: 39, Lemma: ., POS: PUNCT, Dependency: punct, Head: needed, Roleset: None, Synset: None
#  Verb: needed
#   Argument: They, Label: ARG0
#   Argument: just, Label: ARGM-ADV
#   Argument: needed, Label: V
#   Argument: to stay on course and work together, Label: ARG1
#  Verb: stay
#   Argument: They, Label: ARG1
#   Argument: stay, Label: V
#   Argument: on course, Label: ARG3
#  Verb: work
#   Argument: They, Label: ARG0
#   Argument: work, Label: V
#   Argument: together, Label: ARGM-MNR
#  Coreference chain: 3
#   Mention: They, Label: REF3

# %% [markdown]
# ## 2. Visualizing annotated text
#
# This code generates and displays an SVG visualization of annotated text from a `doc` object using the `draw_text` function from the `semhyp.drawer` module. It includes various annotations such as text, dependency relations, part of speech, tags, named entities, rolesets, semantic role labels, coreference chains, and WordNet synsets. The visualization is then displayed in a Jupyter notebook using the HTML function from `IPython.display`.

# %%
from IPython.display import HTML

FONT_SIZE = 16
svg = semhyp.draw_text(doc, 
                       show_spans=True, 
                       annos="text, dep, pos, tag, ent, roleset, srl, coref, synset", 
                       font_height=FONT_SIZE, font_width=FONT_SIZE*0.7, offset=5, margin=10)

HTML(svg)
# Out:
# <svg width="1274.3999999999999" height="1400.78" xmlns="http://www.w3.org/2000/svg"
#     font-family="courier new"
#     font-size="16"
#     style="background: white">
#     <style>
#         .center-text {
#             fill: black;
#             text-anchor: middle;
#         }
#         .left-text {
#             fill: black;
#             text-anchor: left;
#         }
#
#         .typeP {fill: lightcoral;}
#         .typeC {fill: lightblue;}
#         .typeT {fill: lemonchiffon;}
#         .typeJ {fill: moccasin;}
#         .typeM {fill: honeydew;}
#         .typeB {fill: lightgrey;}
#
#         .word {fill: black} .lemma {fill: grey} .ent {fill: blue} .srl {fill: green} .coref {fill: red}
#
#     </style>
#     <!-- Define an arrow marker -->
#     <defs>
#         <marker id="arrowhead"
#                 markerWidth="11.2" markerHeight="7.839999999999999"
#                 refX="11.2" refY="3.9199999999999995"
#                 orient="auto" markerUnits="strokeWidth">
#             <!-- Arrowhead path -->
#             <polygon points="0 0, 11.2 3.9199999999999995, 0 7.839999999999999" fill="grey" />
#         </marker>
#     </defs>
#     <text x="10" y="26"   style="font-weight: bold" >0: Patrick knew about IBM&#x27;s plans, but he was ready to ignore them.</text>
# <path d="M 133.39999999999998 203.82 A 42.19999999999999 22.319999999999993 0 0 0 49.0 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="91.19999999999999" y="176.5" class="center-text">nsubj</text>
# <path d="M 138.39999999999998 153.82 L 138.39999999999998 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="138.39999999999998" y="148.82" class="center-text">ROOT</text>
# <path d="M 143.39999999999998 203.82 A 36.900000000000006 19.140000000000004 0 0 1 217.2 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="180.29999999999998" y="179.67999999999998" class="center-text">prep</text>
# <path d="M 391.0 203.82 A 58.900000000000006 32.34 0 0 0 273.2 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="332.1" y="166.48" class="center-text">poss</text>
# <path d="M 278.2 203.82 A 22.5 10.5 0 0 1 323.2 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="300.7" y="188.32" class="center-text">case</text>
# <path d="M 222.2 203.82 A 86.9 49.14 0 0 1 396.0 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="309.1" y="149.68" class="center-text">pobj</text>
# <path d="M 143.39999999999998 203.82 A 165.7 96.41999999999999 0 0 1 474.79999999999995 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="309.09999999999997" y="102.4" class="center-text">punct</text>
# <path d="M 143.39999999999998 203.82 A 193.7 113.21999999999998 0 0 1 530.8 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="337.09999999999997" y="85.60000000000001" class="center-text">cc</text>
# <path d="M 637.8 203.82 A 25.5 12.299999999999999 0 0 0 586.8 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="612.3" y="186.51999999999998" class="center-text">nsubj</text>
# <path d="M 143.39999999999998 203.82 A 249.7 146.82 0 0 1 642.8 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="393.09999999999997" y="52.0" class="center-text">conj</text>
# <path d="M 647.8 203.82 A 39.5 20.7 0 0 1 726.8 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="687.3" y="178.12" class="center-text">acomp</text>
# <path d="M 883.5999999999999 203.82 A 39.39999999999998 20.639999999999986 0 0 0 804.8 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="844.1999999999999" y="178.18" class="center-text">aux</text>
# <path d="M 731.8 203.82 A 78.39999999999998 44.039999999999985 0 0 1 888.5999999999999 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="810.1999999999999" y="154.78" class="center-text">xcomp</text>
# <path d="M 893.5999999999999 203.82 A 39.60000000000002 20.760000000000012 0 0 1 972.8 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="933.1999999999999" y="178.05999999999997" class="center-text">dobj</text>
# <path d="M 647.8 203.82 A 187.89999999999998 109.73999999999998 0 0 1 1023.5999999999999 203.82" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="835.6999999999999" y="89.08000000000001" class="center-text">punct</text>
# <text x="49.0" y="219.82"  class="center-text text"  >Patrick</text>
# <text x="49.0" y="235.82"  class="center-text dep"  >nsubj</text>
# <text x="49.0" y="251.82"  class="center-text pos"  >PROPN</text>
# <text x="49.0" y="267.82"  class="center-text tag"  >NNP</text>
# <rect x="10.0" y="271.82" width="78.39999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="49.199999999999996" y="283.82"  class="center-text ent"  >PERSON</text>
# <text x="49.0" y="299.82"  class="center-text roleset"  > </text>
# <rect x="10.0" y="303.82" width="78.39999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="49.199999999999996" y="315.82"  class="center-text srl"  >ARG0</text>
# <rect x="10.0" y="351.82" width="78.39999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="49.199999999999996" y="363.82"  class="center-text coref"  >MAIN1</text>
# <text x="49.0" y="395.82"  class="center-text synset"  > </text>
# <text x="138.39999999999998" y="219.82"  class="center-text text"  >knew</text>
# <text x="138.39999999999998" y="235.82"  class="center-text dep"  >ROOT</text>
# <text x="138.39999999999998" y="251.82"  class="center-text pos"  >VERB</text>
# <text x="138.39999999999998" y="267.82"  class="center-text tag"  >VBD</text>
# <text x="138.39999999999998" y="299.82"  class="center-text roleset"  >know.01</text>
# <rect x="88.39999999999999" y="303.82" width="100.8" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="138.79999999999998" y="315.82"  class="center-text srl"  >V</text>
# <text x="138.39999999999998" y="395.82"  class="center-text synset"  >know.v.01</text>
# <text x="217.2" y="219.82"  class="center-text text"  >about</text>
# <text x="217.2" y="235.82"  class="center-text dep"  >prep</text>
# <text x="217.2" y="251.82"  class="center-text pos"  >ADP</text>
# <text x="217.2" y="267.82"  class="center-text tag"  >IN</text>
# <text x="217.2" y="299.82"  class="center-text roleset"  > </text>
# <rect x="189.2" y="303.82" width="257.6" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="318.0" y="315.82"  class="center-text srl"  >ARG1</text>
# <text x="217.2" y="395.82"  class="center-text synset"  > </text>
# <text x="273.2" y="219.82"  class="center-text text"  >IBM</text>
# <text x="273.2" y="235.82"  class="center-text dep"  >poss</text>
# <text x="273.2" y="251.82"  class="center-text pos"  >PROPN</text>
# <text x="273.2" y="267.82"  class="center-text tag"  >NNP</text>
# <rect x="245.2" y="271.82" width="56.0" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="273.2" y="283.82"  class="center-text ent"  >ORG</text>
# <text x="273.2" y="299.82"  class="center-text roleset"  > </text>
# <rect x="245.2" y="367.82" width="201.6" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="346.0" y="379.82"  class="center-text coref"  >MAIN2</text>
# <text x="273.2" y="395.82"  class="center-text synset"  > </text>
# <text x="323.2" y="219.82"  class="center-text text"  >&#x27;s</text>
# <text x="323.2" y="235.82"  class="center-text dep"  >case</text>
# <text x="323.2" y="251.82"  class="center-text pos"  >PART</text>
# <text x="323.2" y="267.82"  class="center-text tag"  >POS</text>
# <te

# %% [markdown]
# This code dislays SVG visualization of one sentence from `doc` object. All available annotations are included.

# %%
sents = list(doc.sents)

svg = semhyp.draw_text(sents[0])
HTML(svg)
# Out:
# <svg width="883.1999999999999" height="351.28" xmlns="http://www.w3.org/2000/svg"
#     font-family="courier new"
#     font-size="16"
#     style="background: white">
#     <style>
#         .center-text {
#             fill: black;
#             text-anchor: middle;
#         }
#         .left-text {
#             fill: black;
#             text-anchor: left;
#         }
#
#         .typeP {fill: lightcoral;}
#         .typeC {fill: lightblue;}
#         .typeT {fill: lemonchiffon;}
#         .typeJ {fill: moccasin;}
#         .typeM {fill: honeydew;}
#         .typeB {fill: lightgrey;}
#
#         .word {fill: black} .lemma {fill: grey} .ent {fill: blue} .srl {fill: green} .coref {fill: red}
#
#     </style>
#     <!-- Define an arrow marker -->
#     <defs>
#         <marker id="arrowhead"
#                 markerWidth="11.2" markerHeight="7.839999999999999"
#                 refX="11.2" refY="3.9199999999999995"
#                 orient="auto" markerUnits="strokeWidth">
#             <!-- Arrowhead path -->
#             <polygon points="0 0, 11.2 3.9199999999999995, 0 7.839999999999999" fill="grey" />
#         </marker>
#     </defs>
#     <text x="0" y="16"   style="font-weight: bold" >0: Patrick knew about IBM&#x27;s plans, but he was ready to ignore them.</text>
# <path d="M 105.2 159.27999999999997 A 36.1 18.66 0 0 0 33.0 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="69.1" y="135.61999999999998" class="center-text">nsubj</text>
# <path d="M 110.2 109.27999999999997 L 110.2 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="110.2" y="104.27999999999997" class="center-text">ROOT</text>
# <path d="M 115.2 159.27999999999997 A 31.199999999999996 15.719999999999997 0 0 1 177.6 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="146.4" y="138.55999999999997" class="center-text">prep</text>
# <path d="M 326.0 159.27999999999997 A 50.2 27.12 0 0 0 225.6 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="275.8" y="127.15999999999997" class="center-text">poss</text>
# <path d="M 230.6 159.27999999999997 A 19.000000000000014 8.400000000000007 0 0 1 268.6 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="249.60000000000002" y="145.87999999999997" class="center-text">case</text>
# <path d="M 182.6 159.27999999999997 A 74.2 41.52 0 0 1 331.0 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="256.8" y="112.75999999999996" class="center-text">pobj</text>
# <path d="M 115.2 159.27999999999997 A 141.6 81.96 0 0 1 398.4 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="256.8" y="72.31999999999998" class="center-text">punct</text>
# <path d="M 115.2 159.27999999999997 A 165.6 96.36 0 0 1 446.4 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="280.8" y="57.91999999999997" class="center-text">cc</text>
# <path d="M 527.8 159.27999999999997 A 19.19999999999999 8.519999999999992 0 0 0 489.4 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="508.59999999999997" y="145.76" class="center-text">nsubj</text>
# <path d="M 115.2 159.27999999999997 A 208.79999999999998 122.27999999999999 0 0 1 532.8 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="324.0" y="31.999999999999986" class="center-text">conj</text>
# <path d="M 537.8 159.27999999999997 A 33.5 17.099999999999998 0 0 1 604.8 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="571.3" y="137.17999999999998" class="center-text">acomp</text>
# <path d="M 738.1999999999999 159.27999999999997 A 33.19999999999999 16.91999999999999 0 0 0 671.8 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="705.0" y="137.35999999999999" class="center-text">aux</text>
# <path d="M 609.8 159.27999999999997 A 66.69999999999999 37.01999999999999 0 0 1 743.1999999999999 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="676.5" y="117.25999999999999" class="center-text">xcomp</text>
# <path d="M 748.1999999999999 159.27999999999997 A 33.80000000000001 17.280000000000005 0 0 1 815.8 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="782.0" y="136.99999999999997" class="center-text">dobj</text>
# <path d="M 537.8 159.27999999999997 A 160.7 93.41999999999999 0 0 1 859.1999999999999 159.27999999999997" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <text x="698.5" y="60.859999999999985" class="center-text">punct</text>
# <text x="33.0" y="175.27999999999997"  class="center-text text"  >Patrick</text>
# <text x="33.0" y="191.27999999999997"  class="center-text lemma"  >Patrick</text>
# <text x="33.0" y="207.27999999999997"  class="center-text pos"  >PROPN</text>
# <text x="33.0" y="223.27999999999997"  class="center-text tag"  >NNP</text>
# <rect x="0.0" y="227.27999999999997" width="67.2" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="33.6" y="239.27999999999997"  class="center-text ent"  >PERSON</text>
# <text x="33.0" y="255.27999999999997"  class="center-text roleset"  > </text>
# <rect x="0.0" y="259.28" width="67.2" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="33.6" y="271.28"  class="center-text srl"  >ARG0</text>
# <rect x="0.0" y="307.28" width="67.2" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="33.6" y="319.28"  class="center-text coref"  >MAIN1</text>
# <text x="33.0" y="351.28"  class="center-text synset"  > </text>
# <text x="110.2" y="175.27999999999997"  class="center-text text"  >knew</text>
# <text x="110.2" y="191.27999999999997"  class="center-text lemma"  >know</text>
# <text x="110.2" y="207.27999999999997"  class="center-text pos"  >VERB</text>
# <text x="110.2" y="223.27999999999997"  class="center-text tag"  >VBD</text>
# <text x="110.2" y="255.27999999999997"  class="center-text roleset"  >know.01</text>
# <rect x="67.2" y="259.28" width="86.39999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="110.4" y="271.28"  class="center-text srl"  >V</text>
# <text x="110.2" y="351.28"  class="center-text synset"  >know.v.01</text>
# <text x="177.6" y="175.27999999999997"  class="center-text text"  >about</text>
# <text x="177.6" y="191.27999999999997"  class="center-text lemma"  >about</text>
# <text x="177.6" y="207.27999999999997"  class="center-text pos"  >ADP</text>
# <text x="177.6" y="223.27999999999997"  class="center-text tag"  >IN</text>
# <text x="177.6" y="255.27999999999997"  class="center-text roleset"  > </text>
# <rect x="153.6" y="259.28" width="220.8" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="264.0" y="271.28"  class="center-text srl"  >ARG1</text>
# <text x="177.6" y="351.28"  class="center-text synset"  > </text>
# <text x="225.6" y="175.27999999999997"  class="center-text text"  >IBM</text>
# <text x="225.6" y="191.27999999999997"  class="center-text lemma"  >IBM</text>
# <text x="225.6" y="207.27999999999997"  class="center-text pos"  >PROPN</text>
# <text x="225.6" y="223.27999999999997"  class="center-text tag"  >NNP</text>
# <rect x="201.6" y="227.27999999999997" width="48.0" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="225.6" y="239.27999999999997"  class="center-text ent"  >ORG</text>
# <text x="225.6" y="255.27999999999997"  class="center-text roleset"  > </text>
# <rect x="201.6" y="323.28" width="172.8" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"   />
# <text x="288.0" y="335

# %% [markdown]
# ## 3. Parsing annotated text into semantic hypergraph
#
# This code parses annotated text of a document `doc` by using `semhyp.parse` function and returns hypergraph `graph`. This hypergraph is implemented as a list whose elements are semantic hyperedges for each sentence in the document.
#
# The first sentence "Patrick knew about IBM's plans, but he was ready to ignore them." has following semantic hyperedge:
#
# ```
# (but/J
#   (knew/Pd.sx:01.<f
#     patrick/Cp..s.p
#     (about/T
#     ('s/Bp ibm/Cp..s.o plans/Cc..p)))
#   (was/Pd.sc:12.<f
#     (+/Jc.rm.rp he/Ci patrick/Cp..s.p)
#     (+/Br.am
#       ready/Ca
#       ((to/Mi.< ignore/P.-o:01.-i)
#         (+/Jc.rm.rp
#           he/Ci
#           patrick/Cp..s.p)
#         (+/Jc.rm.rc
#           them/Ci
#           ('s/Bp ibm/Cp..s.o plans/Cc..p))))))
# ```

# %%
graph = semhyp.parse(doc)
graph
# Out:
# [(but/J (knew/Pd.sx:01.<f patrick/Cp..s.p (about/T ('s/Bp ibm/Cp..s.o plans/Cc..p))) (was/Pd.sc:12.<f (+/Jc.rm.rp he/Ci patrick/Cp..s.p) (+/Br.am ready/Ca ((to/Mi.< ignore/P.-o:01.-i) (+/Jc.rm.rp he/Ci patrick/Cp..s.p) (+/Jc.rm.rc them/Ci ('s/Bp ibm/Cp..s.o plans/Cc..p)))))),
#  (focused/Pd.sxx:02h.<f (+/Jc.rm.rp he/Ci patrick/Cp..s.p) (on/T ((+/Jc.rm.rp his/Mp patrick/Cp..s.p) (own/Ma.< plan/Cc..s))) (believing/P.-r:01.|pg (+/Jc.rm.rp he/Ci patrick/Cp..s.p) ((could/Mm.< succeed/P.sx:0t.-i) ((+/Jc.rm.rp his/Mp patrick/Cp..s.p) team/Cc..s) still/M))),
#  (needed/Pd.sxr:0r1.<f (+/Jc.rm.rc they/Ci (his/Mp team/Cc..s)) just/M (and/J ((to/Mi.< stay/P.-x:13.-i) (+/Jc.rm.rc they/Ci (his/Mp team/Cc..s)) (on/T course/Cc..s)) (work/P.-x:0m.-i (+/Jc.rm.rc they/Ci (his/Mp team/Cc..s)) together/M)))]

# %% [markdown]
# The following code retrieves the first hyperedge from the hypergraph and outputs various details about it. It prints the original edge, its simplified version, and its rooted version. It then iterates over the atoms in the edge, printing details such as the atom's label, type, roles, morphology, and entity. Finally, it iterates over the subedges of the edge, printing each subedge in its simplified form.

# %%
# Assuming `edge` is the first semantic hyperedge in `graph`

edge = graph[0]
print("Edge:\n  ", edge)
print("Simplified edge:\n  ", edge.simplify())
print("Rooted edge:\n  ", edge.roots())

print()
# Iterate over atoms in the edge
for atom in edge.atoms():
    print("Atom:", atom, "label:", atom.label(), "type:", atom.type(), "roles:", atom.roles(), "morph:", atom.morph(), "entity:", atom.entity())
    

print()
# Iterate over subedges of the edge
for subedge in edge.subedges():
    print("Subedge:", subedge.simplify())
# Out:
# Edge:
#    (but/J (knew/Pd.sx:01.<f patrick/Cp..s.p (about/T ('s/Bp ibm/Cp..s.o plans/Cc..p))) (was/Pd.sc:12.<f (+/Jc.rm.rp he/Ci patrick/Cp..s.p) (+/Br.am ready/Ca ((to/Mi.< ignore/P.-o:01.-i) (+/Jc.rm.rp he/Ci patrick/Cp..s.p) (+/Jc.rm.rc them/Ci ('s/Bp ibm/Cp..s.o plans/Cc..p))))))
# Simplified edge:
#    (but/J (knew/P patrick/C (about/T ('s/B ibm/C plans/C))) (was/P (+/J he/C patrick/C) (+/B ready/C ((to/M ignore/P) (+/J he/C patrick/C) (+/J them/C ('s/B ibm/C plans/C))))))
# Rooted edge:
#    (but (knew patrick (about ('s ibm plans))) (was (+ he patrick) (+ ready ((to ignore) (+ he patrick) (+ them ('s ibm plans))))))
#
# Atom: but/J label: but type: J roles: None morph: None entity: None
# Atom: plans/Cc..p label: plans type: Cc roles: ('',) morph: ('p',) entity: None
# Atom: patrick/Cp..s.p label: patrick type: Cp roles: ('',) morph: ('s',) entity: ('p',)
# Atom: ibm/Cp..s.o label: ibm type: Cp roles: ('',) morph: ('s',) entity: ('o',)
# Atom: knew/Pd.sx:01.<f label: knew type: Pd roles: ('sx', '01') morph: ('<f',) entity: None
# Atom: about/T label: about type: T roles: None morph: None entity: None
# Atom: 's/Bp label: 's type: Bp roles: None morph: None entity: None
# Atom: was/Pd.sc:12.<f label: was type: Pd roles: ('sc', '12') morph: ('<f',) entity: None
# Atom: +/Br.am label: + type: Br roles: ('am',) morph: None entity: None
# Atom: +/Jc.rm.rp label: + type: Jc roles: ('rm',) morph: ('rp',) entity: None
# Atom: ignore/P.-o:01.-i label: ignore type: P roles: ('-o', '01') morph: ('-i',) entity: None
# Atom: to/Mi.< label: to type: Mi roles: ('<',) morph: None entity: None
# Atom: he/Ci label: he type: Ci roles: None morph: None entity: None
# Atom: ready/Ca label: ready type: Ca roles: None morph: None entity: None
# Atom: +/Jc.rm.rc label: + type: Jc roles: ('rm',) morph: ('rc',) entity: None
# Atom: them/Ci label: them type: Ci roles: None morph: None entity: None
#
# Subedge: about/T
# Subedge: ibm/C
# Subedge: plans/C
# Subedge: was/P
# Subedge: +/B
# Subedge: ready/C
# Subedge: (but/J (knew/P patrick/C (about/T ('s/B ibm/C plans/C))) (was/P (+/J he/C patrick/C) (+/B ready/C ((to/M ignore/P) (+/J he/C patrick/C) (+/J them/C ('s/B ibm/C plans/C))))))
# Subedge: to/M
# Subedge: +/J
# Subedge: ('s/B ibm/C plans/C)
# Subedge: (+/J them/C ('s/B ibm/C plans/C))
# Subedge: ((to/M ignore/P) (+/J he/C patrick/C) (+/J them/C ('s/B ibm/C plans/C)))
# Subedge: (knew/P patrick/C (about/T ('s/B ibm/C plans/C)))
# Subedge: (about/T ('s/B ibm/C plans/C))
# Subedge: (+/B ready/C ((to/M ignore/P) (+/J he/C patrick/C) (+/J them/C ('s/B ibm/C plans/C))))
# Subedge: (+/J he/C patrick/C)
# Subedge: (to/M ignore/P)
# Subedge: but/J
# Subedge: knew/P
# Subedge: patrick/C
# Subedge: 's/B
# Subedge: +/J
# Subedge: he/C
# Subedge: ignore/P
# Subedge: them/C
# Subedge: (was/P (+/J he/C patrick/C) (+/B ready/C ((to/M ignore/P) (+/J he/C patrick/C) (+/J them/C ('s/B ibm/C plans/C)))))

# %% [markdown]
# ## 4. Visualizing semantic hypergraph
#
# This code generates and displays an SVG visualization of a semantic hypergraph from a `graph` object using the `draw_hyper` function from the `semhyp.drawer` module. The idea of semantic hypergraph visualization is to represent the hypergraph as a tree. Representing a hypergraph as a tree involves representing a hyperedge as a tree whose root node is the first subedge, and whose subnodes are the remaining subedges. If a remaining subnode is not an atom or a coreference subedge whose subedges are not in the same sentence, the representation continues recursively.
#
# Therefore, the first semantic hyperedge:
#
# ```
# (but/J
#   (knew/Pd.sx:01.<f
#     patrick/Cp..s.p
#     (about/T
#     ('s/Bp ibm/Cp..s.o plans/Cc..p)))
#   (was/Pd.sc:12.<f
#     (+/Jc.rm.rp he/Ci patrick/Cp..s.p)
#     (+/Br.am
#       ready/Ca
#       ((to/Mi.< ignore/P.-o:01.-i)
#         (+/Jc.rm.rp
#           he/Ci
#           patrick/Cp..s.p)
#         (+/Jc.rm.rc
#           them/Ci
#           ('s/Bp ibm/Cp..s.o plans/Cc..p))))))
# ```
#
# is represented as
#
# ```
#            ------------but/J-------
#           /                        \
#        knew/P                 ---- was/P ------
#       /      \               /                  \
#  Patrick/C  about/T        +/J                 +/B
#               |           /   \                /  \
#             's/B        he/C [Patrick/C]  ready/C  (to/M ignore/P)
#              /  \                                        |
#         IBM/C   plans/C                                 +/J
#                                                         /   \
#                                                     them/C  ['s/B]
#                                                             [/  \]
#                                                         [IBM/C   plans/C]
# ```

# %%
FONT_SIZE = 16
svg = semhyp.draw_hyper(graph, font_height=FONT_SIZE, font_width=FONT_SIZE*0.7, margin=10)
HTML(svg)
# Out:
# <svg width="1072.8" height="736.0" xmlns="http://www.w3.org/2000/svg"
#     font-family="courier new"
#     font-size="16"
#     style="background: white">
#     <style>
#         .center-text {
#             fill: black;
#             text-anchor: middle;
#         }
#         .left-text {
#             fill: black;
#             text-anchor: left;
#         }
#
#         .typeP {fill: lightcoral;}
#         .typeC {fill: lightblue;}
#         .typeT {fill: lemonchiffon;}
#         .typeJ {fill: moccasin;}
#         .typeM {fill: honeydew;}
#         .typeB {fill: lightgrey;}
#
#         .word {fill: black} .lemma {fill: grey} .ent {fill: blue} .srl {fill: green} .coref {fill: red}
#
#     </style>
#     <!-- Define an arrow marker -->
#     <defs>
#         <marker id="arrowhead"
#                 markerWidth="11.2" markerHeight="7.839999999999999"
#                 refX="11.2" refY="3.9199999999999995"
#                 orient="auto" markerUnits="strokeWidth">
#             <!-- Arrowhead path -->
#             <polygon points="0 0, 11.2 3.9199999999999995, 0 7.839999999999999" fill="grey" />
#         </marker>
#     </defs>
#     <line x1="192.0" y1="178.0" x2="150.0" y2="214.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="206.0" y1="178.0" x2="228.2" y2="214.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="205.0" y1="130.0" x2="200.0" y2="166.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="144.0" y1="82.0" x2="60.0" y2="118.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="166.0" y1="82.0" x2="205.0" y2="118.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="339.4" y1="130.0" x2="334.4" y2="166.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="507.19999999999993" y1="226.0" x2="502.19999999999993" y2="262.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="553.1999999999999" y1="178.0" x2="507.19999999999993" y2="214.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="507.19999999999993" y="211.0" class="center-text" font-size="12.0">rm</text>
# <line x1="507.59999999999997" y1="130.0" x2="418.59999999999997" y2="166.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="518.5999999999999" y1="130.0" x2="553.1999999999999" y2="166.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="553.1999999999999" y="163.0" class="center-text" font-size="12.0">-o.01</text>
# <line x1="475.4" y1="82.0" x2="339.4" y2="118.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="339.4" y="115.0" class="center-text" font-size="12.0">rm</text>
# <line x1="493.4" y1="82.0" x2="512.5999999999999" y2="118.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="512.5999999999999" y="115.0" class="center-text" font-size="12.0">am</text>
# <line x1="330.0" y1="34.0" x2="155.0" y2="70.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="155.0" y="67.0" class="center-text" font-size="12.0">sx.01</text>
# <line x1="348.0" y1="34.0" x2="485.4" y2="70.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="485.4" y="67.0" class="center-text" font-size="12.0">sc.12</text>
# <line x1="340.0" y1="22.0" x2="340.0" y2="22.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <path d="M 553.1999999999999,178.0 Q 446.29999999999995,188.7420967563166 339.4,134.0" stroke="black" stroke-width="0.5" stroke-dasharray="5, 5" fill="none" marker-end="url(#arrowhead)" /><text x="339.4" y="143.0" class="center-text" font-size="75%">rm</text>
# <path d="M 507.19999999999993,226.0 Q 353.59999999999997,250.55025671250374 200.0,182.0" stroke="black" stroke-width="0.5" stroke-dasharray="5, 5" fill="none" marker-end="url(#arrowhead)" />
# <path d="M 339.4,130.0 Q 199.7,173.9142946976327 60.0,134.0" stroke="black" stroke-width="0.5" stroke-dasharray="5, 5" fill="none" marker-end="url(#arrowhead)" />
# <rect x="312.0" y="22.0" width="56.0" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeJ"   />
# <text x="340.0" y="34.0"  class="center-text"  >but/J</text>
# <rect x="122.0" y="70.0" width="67.19999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeP"   />
# <text x="155.6" y="82.0"  class="center-text"  >knew/P</text>
# <rect x="457.4" y="70.0" width="56.0" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeP"   />
# <text x="485.4" y="82.0"  class="center-text"  >was/P</text>
# <rect x="10.0" y="118.0" width="100.8" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeC"   />
# <text x="60.4" y="130.0"  class="center-text"  >patrick/C</text>
# <rect x="166.0" y="118.0" width="78.39999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeT"   />
# <text x="205.2" y="130.0"  class="center-text"  >about/T</text>
# <rect x="323.4" y="118.0" width="33.599999999999994" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeJ"   />
# <text x="340.2" y="130.0"  class="center-text"  >+/J</text>
# <rect x="496.59999999999997" y="118.0" width="33.599999999999994" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeB"   />
# <text x="513.4" y="130.0"  class="center-text"  >+/B</text>
# <rect x="178.0" y="166.0" width="44.8" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeB"   />
# <text x="200.4" y="178.0"  class="center-text"  >&#x27;s/B</text>
# <rect x="312.4" y="166.0" width="44.8" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeC"   />
# <text x="334.79999999999995" y="178.0"  class="center-text"  >he/C</text>
# <rect x="379.59999999999997" y="166.0" width="78.39999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeC"   />
# <text x="418.79999999999995" y="178.0"  class="center-text"  >ready/C</text>
# <rect x="469.19999999999993" y="166.0" width="168.0" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeP"   />
# <text x="553.1999999999999" y="178.0"  class="center-text"  >(to/M ignore/P)</text>
# <rect x="122.0" y="214.0" width="56.0" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeC"   />
# <text x="150.0" y="226.0"  class="center-text"  >ibm/C</text>
# <rect x="189.2" y="214.0" width="78.39999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeC"   />
# <text x="228.39999999999998" y="226.0"  class="center-text"  >plans/C</text>
# <rect x="491.19999999999993" y="214.0" width="33.599999999999994" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeJ"   />
# <text x="507.99999999999994" y="226.0"  class="center-text"  >+/J</text>
# <rect x="469.19999999999993" y="262.0" width="67.19999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeC"   />
# <text x="502.79999999999995" y="274.0"  class="center-text"  >them/C</text>
# <line x1="88.0" y1="372.0" x2="32.0" y2="408.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="99.0" y1="372.0" x2="116.0" y2="408.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="406.2" y1="372.0" x2="401.2" y2="408.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="401.2" y="405.0" class="center-text" font-size="12.0">Cc</text>
# <line x1="818.1999999999999" y1="420.0" x2="805.1999999999999" y2="456.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="805.1999999999999" y="453.0" class="center-text" font-size="12.0">Cc

# %% [markdown]
# This code dislays SVG visualization of one semantic hyperedge from `graph` object.

# %%
svg = semhyp.draw_hyper(graph[0], font_height=FONT_SIZE, font_width=FONT_SIZE*0.7, margin=10)
HTML(svg)
# Out:
# <svg width="647.1999999999999" height="300.0" xmlns="http://www.w3.org/2000/svg"
#     font-family="courier new"
#     font-size="16"
#     style="background: white">
#     <style>
#         .center-text {
#             fill: black;
#             text-anchor: middle;
#         }
#         .left-text {
#             fill: black;
#             text-anchor: left;
#         }
#
#         .typeP {fill: lightcoral;}
#         .typeC {fill: lightblue;}
#         .typeT {fill: lemonchiffon;}
#         .typeJ {fill: moccasin;}
#         .typeM {fill: honeydew;}
#         .typeB {fill: lightgrey;}
#
#         .word {fill: black} .lemma {fill: grey} .ent {fill: blue} .srl {fill: green} .coref {fill: red}
#
#     </style>
#     <!-- Define an arrow marker -->
#     <defs>
#         <marker id="arrowhead"
#                 markerWidth="11.2" markerHeight="7.839999999999999"
#                 refX="11.2" refY="3.9199999999999995"
#                 orient="auto" markerUnits="strokeWidth">
#             <!-- Arrowhead path -->
#             <polygon points="0 0, 11.2 3.9199999999999995, 0 7.839999999999999" fill="grey" />
#         </marker>
#     </defs>
#     <line x1="192.0" y1="178.0" x2="150.0" y2="214.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="206.0" y1="178.0" x2="228.2" y2="214.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="205.0" y1="130.0" x2="200.0" y2="166.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="144.0" y1="82.0" x2="60.0" y2="118.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="166.0" y1="82.0" x2="205.0" y2="118.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="339.4" y1="130.0" x2="334.4" y2="166.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="507.19999999999993" y1="226.0" x2="502.19999999999993" y2="262.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="553.1999999999999" y1="178.0" x2="507.19999999999993" y2="214.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="507.19999999999993" y="211.0" class="center-text" font-size="12.0">rm</text>
# <line x1="507.59999999999997" y1="130.0" x2="418.59999999999997" y2="166.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <line x1="518.5999999999999" y1="130.0" x2="553.1999999999999" y2="166.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="553.1999999999999" y="163.0" class="center-text" font-size="12.0">-o.01</text>
# <line x1="475.4" y1="82.0" x2="339.4" y2="118.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="339.4" y="115.0" class="center-text" font-size="12.0">rm</text>
# <line x1="493.4" y1="82.0" x2="512.5999999999999" y2="118.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="512.5999999999999" y="115.0" class="center-text" font-size="12.0">am</text>
# <line x1="330.0" y1="34.0" x2="155.0" y2="70.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="155.0" y="67.0" class="center-text" font-size="12.0">sx.01</text>
# <line x1="348.0" y1="34.0" x2="485.4" y2="70.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" /><text x="485.4" y="67.0" class="center-text" font-size="12.0">sc.12</text>
# <line x1="340.0" y1="22.0" x2="340.0" y2="22.0" stroke="black" stroke-width="0.5" fill="none" marker-end="url(#arrowhead)" />
# <path d="M 553.1999999999999,178.0 Q 446.29999999999995,188.7420967563166 339.4,134.0" stroke="black" stroke-width="0.5" stroke-dasharray="5, 5" fill="none" marker-end="url(#arrowhead)" /><text x="339.4" y="143.0" class="center-text" font-size="75%">rm</text>
# <path d="M 507.19999999999993,226.0 Q 353.59999999999997,250.55025671250374 200.0,182.0" stroke="black" stroke-width="0.5" stroke-dasharray="5, 5" fill="none" marker-end="url(#arrowhead)" />
# <path d="M 339.4,130.0 Q 199.7,173.9142946976327 60.0,134.0" stroke="black" stroke-width="0.5" stroke-dasharray="5, 5" fill="none" marker-end="url(#arrowhead)" />
# <rect x="312.0" y="22.0" width="56.0" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeJ"   />
# <text x="340.0" y="34.0"  class="center-text"  >but/J</text>
# <rect x="122.0" y="70.0" width="67.19999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeP"   />
# <text x="155.6" y="82.0"  class="center-text"  >knew/P</text>
# <rect x="457.4" y="70.0" width="56.0" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeP"   />
# <text x="485.4" y="82.0"  class="center-text"  >was/P</text>
# <rect x="10.0" y="118.0" width="100.8" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeC"   />
# <text x="60.4" y="130.0"  class="center-text"  >patrick/C</text>
# <rect x="166.0" y="118.0" width="78.39999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeT"   />
# <text x="205.2" y="130.0"  class="center-text"  >about/T</text>
# <rect x="323.4" y="118.0" width="33.599999999999994" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeJ"   />
# <text x="340.2" y="130.0"  class="center-text"  >+/J</text>
# <rect x="496.59999999999997" y="118.0" width="33.599999999999994" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeB"   />
# <text x="513.4" y="130.0"  class="center-text"  >+/B</text>
# <rect x="178.0" y="166.0" width="44.8" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeB"   />
# <text x="200.4" y="178.0"  class="center-text"  >&#x27;s/B</text>
# <rect x="312.4" y="166.0" width="44.8" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeC"   />
# <text x="334.79999999999995" y="178.0"  class="center-text"  >he/C</text>
# <rect x="379.59999999999997" y="166.0" width="78.39999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeC"   />
# <text x="418.79999999999995" y="178.0"  class="center-text"  >ready/C</text>
# <rect x="469.19999999999993" y="166.0" width="168.0" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeP"   />
# <text x="553.1999999999999" y="178.0"  class="center-text"  >(to/M ignore/P)</text>
# <rect x="122.0" y="214.0" width="56.0" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeC"   />
# <text x="150.0" y="226.0"  class="center-text"  >ibm/C</text>
# <rect x="189.2" y="214.0" width="78.39999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeC"   />
# <text x="228.39999999999998" y="226.0"  class="center-text"  >plans/C</text>
# <rect x="491.19999999999993" y="214.0" width="33.599999999999994" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeJ"   />
# <text x="507.99999999999994" y="226.0"  class="center-text"  >+/J</text>
# <rect x="469.19999999999993" y="262.0" width="67.19999999999999" height="16" rx="3.2" stroke="black" stroke-width="0.5" fill="white"  class="typeC"   />
# <text x="502.79999999999995" y="274.0"  class="center-text"  >them/C</text>
#
# </svg>
